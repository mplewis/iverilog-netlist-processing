# %%
class IvlModule:
    def __init__(self, name, xtype, ports=None):
        self.name = name
        self.xtype = xtype
        self.ports = ports or []
    
    def __repr__(self):
        return '<IvlModule: %s "%s" (%s ports)>' % (self.xtype, self.name, len(self.ports))

# %%
from enum import Enum


class IvlPortType(Enum):
    reg = 1
    wire = 2
    event = 3


class IvlDataDirection(Enum):
    input = 1
    output = 2


class IvlPort:
    def __init__(self, name, xtype, code_snippet=None, net=None, direction=None):
        self.name = name
        self.xtype = xtype
        self.code_snippet = code_snippet
        self.net = net or set()
        self.direction = direction
        
    def set_net(self, net):
        self.net = net
    
    def remove_net(self, net):
        self.nets.remove(net)
    
    def __repr__(self):
        output = '<IvlPort: '

        if self.direction:
            output += '%s ' % self.direction.name

        output += '%s ' % self.xtype.name

        output += '"%s" ' % self.name

        if self.code_snippet:
            output += '@ %s ' % self.code_snippet

        output = output[:-1]
        output += '>'
        return output

# %%
class IvlNet:
    def __init__(self, xid, name, members=None):
        self.xid = xid
        self.name = name
        self.members = members or set()

    def add_member(self, member):
        self.members.add(member)
        
    def remove_member(self, member):
        self.members.remove(member)
        
    def has_member(self, member):
        return member in self.members
    
    def __repr__(self):
        return '<IvlNet: "%s" (%s members)>' % (self.name, len(self.members))


class IvlNetManager:
    def __init__(self):
        self.nets = {}
    
    def get_net(self, net_id):
        return self.nets[net_id]
    
    def get_or_make_net(self, net_id, net_name):
        if net_id not in self.nets:
            self.nets[net_id] = IvlNet(net_id, net_name)
        return self.nets[net_id]
        
    def _add_member_to_net(self, net_id, net_name, member):
        net = self.get_or_make_net(net_id, net_name)
        net.add_member(member)
        return net
        
    def add_elab_to_net(self, net_id, net_name, elab):
        return self._add_member_to_net(net_id, net_name, elab)
        
    def add_port_to_net(self, net_id, net_name, port):
        net = self._add_member_to_net(net_id, net_name, port)
        port.set_net(net)
        return net

# %%
def leading_spaces(line):
    return len(line) - len(line.lstrip(' '))

# %%
def parse_module_data(lines, net_manager):
    ports = []
    port = None
    skip = True
    for line in lines:
        if leading_spaces(line) == 4:
            if not skip:
                ports.append(port)
                port = None
            else:
                skip = False
            line = line.lstrip(' ')
            if line.startswith('reg') or line.startswith('wire'):
                if line.startswith('reg'):
                    xtype = IvlPortType.reg
                else:
                    xtype = IvlPortType.wire
                name = line.split(': ')[1].split('[')[0]
                direction_raw = line.split('logic')[1].split('(eref')[0].strip(' ')
                try:
                    direction = IvlDataDirection[direction_raw]
                except KeyError:
                    direction = None
                port = IvlPort(name, xtype, direction=direction)
            elif line.startswith('event'):
                xtype = IvlPortType.event
                name = line.split('event ')[1].split(';')[0]
                snippet = line.split('// ')[1]
                port = IvlPort(name, xtype, code_snippet=snippet)
            else:
                skip = True
        elif leading_spaces(line) == 8:
            if port:
                net_id, net_name = line.split(': ')[1].split(' ')
                net_manager.add_port_to_net(net_id, net_name, port)
    if port:
        ports.append(port)
    return ports

# %%
class IvlElabType(Enum):
    net_part_select = 1
    logic = 2
    posedge = 3

    
class IvlElab:
    def __init__(self, xtype):
        self.xtype = xtype
    
    def __repr__(self):
        return '<IvlElab: %s>' % self.xtype.name

        
class IvlElabPosedge(IvlElab):
    def __init__(self, net_in):
        IvlElab.__init__(self, IvlElabType.posedge)
        self.net_in = net_in
    
    def __repr__(self):
        pre = super().__repr__()
        head = pre[:-1]
        output = head
        output += ' input: %s' % self.net_in.name
        output += '>'
        return output


class IvlElabNetPartSelect(IvlElab):
    def __init__(self, net_in, net_out):
        IvlElab.__init__(self, IvlElabType.net_part_select)
        self.net_in = net_in
        self.net_out = net_out
    
    def __repr__(self):
        pre = super().__repr__()
        head = pre[:-1]
        output = head
        output += ' input: %s' % self.net_in.name
        output += ' output: %s' % self.net_out.name
        output += '>'
        return output


class IvlElabLogic(IvlElab):
    def __init__(self, nets_in, net_out):
        IvlElab.__init__(self, IvlElabType.logic)
        self.nets_in = nets_in
        self.net_out = net_out
    
    def __repr__(self):
        pre = super().__repr__()
        head = pre[:-1]
        output = head
        output += ' inputs: %s' % len(self.nets_in)
        output += ' output: %s' % self.net_out.name
        output += '>'
        return output

# %%
def group_lines(lines):
    groups = []
    group = []
    for line in lines:
        if leading_spaces(line) == 0:
            if group:
                groups.append(group)
                group = []
        group.append(line)
    if group:
        groups.append(group)
    return groups

# %%
def parse_module_lines(lines, net_manager):
    module_meta = lines[0]
    module_data = lines[1:]
    name, supertype, module_type_raw, inst_type = module_meta.split(' ')
    module_type = module_type_raw.lstrip('<').rstrip('>')
    ports = parse_module_data(module_data, net_manager)
    module = IvlModule(name, module_type, ports)
    return module

# %%
import re
from pprint import pprint

def parse_netlist_to_sections(raw_netlist):
    section_regex = '[A-Z][A-Z ]*:.*'
    section_finder = re.compile(section_regex)
    sections = {}
    title = None
    section = []
    for line in raw_netlist.split('\n'):
        if section_finder.match(line):
            if not section:
                section = None
            if title:
                sections[title] = section
            section = []
            title, data = line.split(':')
            if data:
                section = data.strip()
        else:
            section.append(line)
    if title:
        sections[title] = section
    return sections

# %%
elab_type_lookup = {
    'NetPartSelect': IvlElabType.net_part_select,
    'posedge': IvlElabType.posedge,
    'logic': IvlElabType.logic
}

def parse_elab_bundle_lines(lines, net_manager):
    xtype_raw = lines[0].split(' -> ')[0].split('(')[0].split(':')[0]
    xtype = elab_type_lookup[xtype_raw]
    input_nets = []
    output_nets = []
    for line in lines[1:]:
        line_split = line.split(' ')
        data_dir = line_split[6]
        net_id = line_split[9]
        net_name = line_split[10]
        net = net_manager.get_or_make_net(net_id, net_name)
        if data_dir == 'I':
            input_nets.append(net)
        elif data_dir == 'O':
            output_nets.append(net)
    if xtype is IvlElabType.net_part_select:
        elab = IvlElabNetPartSelect(input_nets[0], output_nets[0])
    elif xtype is IvlElabType.posedge:
        elab = IvlElabPosedge(input_nets[0])
    elif xtype is IvlElabType.logic:
        elab = IvlElabLogic(input_nets, output_nets[0])
    for net in input_nets + output_nets:
        net_manager.add_elab_to_net(net_id, net_name, elab)
    return elab

# %%
net_manager = IvlNetManager()

with open('netlist') as f:
    raw_netlist = f.read()

sections = parse_netlist_to_sections(raw_netlist)
modules_lines = group_lines(sections['SCOPES'])
elab_bundles_lines = group_lines(sections['ELABORATED NODES'])

modules = []
for lines in modules_lines:
    print(parse_module_lines(lines, net_manager))

pprint(net_manager.nets)

for lines in elab_bundles_lines:
    print(parse_elab_bundle_lines(lines, net_manager))

pprint(net_manager.nets)
# Out:
# <IvlModule: bargraph_testbench "bargraph_testbench" (3 ports)>
# <IvlModule: bargraph3 "bargraph_testbench.b" (20 ports)>
# <IvlModule: ripple3 "bargraph_testbench.r" (5 ports)>
# <IvlModule: tff "bargraph_testbench.r.t2" (5 ports)>
# <IvlModule: tff "bargraph_testbench.r.t1" (5 ports)>
# <IvlModule: tff "bargraph_testbench.r.t0" (5 ports)>
# {'0x7fc052008160': <IvlNet: "bargraph_testbench.r.t0.clk" (3 members)>,
#  '0x7fc052008920': <IvlNet: "bargraph_testbench.r.t0.q" (1 members)>,
#  '0x7fc052008eb0': <IvlNet: "bargraph_testbench.r.tmp0" (4 members)>,
#  '0x7fc0520091a0': <IvlNet: "bargraph_testbench.r.t1.q" (1 members)>,
#  '0x7fc052009740': <IvlNet: "bargraph_testbench.r.tmp1" (4 members)>,
#  '0x7fc052009810': <IvlNet: "bargraph_testbench.r.tmp2" (3 members)>,
#  '0x7fc052009a30': <IvlNet: "bargraph_testbench.r.t2.q" (1 members)>,
#  '0x7fc052009d10': <IvlNet: "bargraph_testbench.b.out" (2 members)>,
#  '0x7fc052009d30': <IvlNet: "bargraph_testbench.b._s0" (1 members)>,
#  '0x7fc05200a050': <IvlNet: "bargraph_testbench.to_bg" (3 members)>,
#  '0x7fc05200a1b0': <IvlNet: "bargraph_testbench.b._s3" (1 members)>,
#  '0x7fc05200a440': <IvlNet: "bargraph_testbench.b._s5" (1 members)>,
#  '0x7fc05200a460': <IvlNet: "bargraph_testbench.b.a" (1 members)>,
#  '0x7fc05200a6d0': <IvlNet: "bargraph_testbench.b._s7" (1 members)>,
#  '0x7fc05200a820': <IvlNet: "bargraph_testbench.b.b" (1 members)>,
#  '0x7fc05200aa80': <IvlNet: "bargraph_testbench.b._s9" (1 members)>,
#  '0x7fc05200ad10': <IvlNet: "bargraph_testbench.b._s11" (1 members)>,
#  '0x7fc05200ae60': <IvlNet: "bargraph_testbench.b.c" (1 members)>,
#  '0x7fc05200b0c0': <IvlNet: "bargraph_testbench.b._s13" (1 members)>,
#  '0x7fc05200b350': <IvlNet: "bargraph_testbench.b._s15" (1 members)>,
#  '0x7fc05200b700': <IvlNet: "bargraph_testbench.b._s17" (1 members)>,
#  '0x7fc05200b720': <IvlNet: "bargraph_testbench.b._s20" (1 members)>,
#  '0x7fc05200b990': <IvlNet: "bargraph_testbench.b._s19" (1 members)>,
#  '0x7fc05200bed0': <IvlNet: "bargraph_testbench.b._s22" (1 members)>,
#  '0x7fc05200c340': <IvlNet: "bargraph_testbench.b._s25" (1 members)>,
#  '0x7fc05200c5d0': <IvlNet: "bargraph_testbench.b._s27" (1 members)>,
#  '0x7fc05200c860': <IvlNet: "bargraph_testbench.b._s29" (1 members)>}
# <IvlElab: posedge input: bargraph_testbench.r.t0.clk>
# <IvlElab: net_part_select input: bargraph_testbench.r.t0.q output: bargraph_testbench.to_bg>
# <IvlElab: posedge input: bargraph_testbench.r.tmp0>
# <IvlElab: net_part_select input: bargraph_testbench.r.t1.q output: bargraph_testbench.to_bg>
# <IvlElab: posedge input: bargraph_testbench.r.tmp1>
# <IvlElab: net_part_select input: bargraph_testbench.r.t2.q output: bargraph_testbench.to_bg>
# <IvlElab: net_part_select input: bargraph_testbench.b._s0 output: bargraph_testbench.b.out>
# <IvlElab: logic inputs: 3 output: bargraph_testbench.b._s0>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s3>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s5>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s7>
# <IvlElab: logic inputs: 2 output: bargraph_testbench.b.a>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s9>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s11>
# <IvlElab: logic inputs: 2 output: bargraph_testbench.b.b>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s13>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s15>
# <IvlElab: logic inputs: 2 output: bargraph_testbench.b.c>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s17>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s19>
# <IvlElab: net_part_select input: bargraph_testbench.b._s20 output: bargraph_testbench.b.out>
# <IvlElab: logic inputs: 3 output: bargraph_testbench.b._s20>
# <IvlElab: net_part_select input: bargraph_testbench.b._s22 output: bargraph_testbench.b.out>
# <IvlElab: logic inputs: 3 output: bargraph_testbench.b._s22>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s25>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s27>
# <IvlElab: net_part_select input: bargraph_testbench.to_bg output: bargraph_testbench.b._s29>
# {'0x7fc052008160': <IvlNet: "bargraph_testbench.r.t0.clk" (4 members)>,
#  '0x7fc052008920': <IvlNet: "bargraph_testbench.r.t0.q" (1 members)>,
#  '0x7fc052008eb0': <IvlNet: "bargraph_testbench.r.tmp0" (5 members)>,
#  '0x7fc0520091a0': <IvlNet: "bargraph_testbench.r.t1.q" (1 members)>,
#  '0x7fc052009740': <IvlNet: "bargraph_testbench.r.tmp1" (5 members)>,
#  '0x7fc052009810': <IvlNet: "bargraph_testbench.r.tmp2" (3 members)>,
#  '0x7fc052009a30': <IvlNet: "bargraph_testbench.r.t2.q" (1 members)>,
#  '0x7fc052009d10': <IvlNet: "bargraph_testbench.b.out" (5 members)>,
#  '0x7fc052009d30': <IvlNet: "bargraph_testbench.b._s0" (1 members)>,
#  '0x7fc05200a050': <IvlNet: "bargraph_testbench.to_bg" (18 members)>,
#  '0x7fc05200a1b0': <IvlNet: "bargraph_testbench.b._s3" (1 members)>,
#  '0x7fc05200a440': <IvlNet: "bargraph_testbench.b._s5" (1 members)>,
#  '0x7fc05200a460': <IvlNet: "bargraph_testbench.b.a" (1 members)>,
#  '0x7fc05200a6d0': <IvlNet: "bargraph_testbench.b._s7" (2 members)>,
#  '0x7fc05200a820': <IvlNet: "bargraph_testbench.b.b" (1 members)>,
#  '0x7fc05200aa80': <IvlNet: "bargraph_testbench.b._s9" (1 members)>,
#  '0x7fc05200ad10': <IvlNet: "bargraph_testbench.b._s11" (2 members)>,
#  '0x7fc05200ae60': <IvlNet: "bargraph_testbench.b.c" (2 members)>,
#  '0x7fc05200b0c0': <IvlNet: "bargraph_testbench.b._s13" (1 members)>,
#  '0x7fc05200b350': <IvlNet: "bargraph_testbench.b._s15" (2 members)>,
#  '0x7fc05200b700': <IvlNet: "bargraph_testbench.b._s17" (1 members)>,
#  '0x7fc05200b720': <IvlNet: "bargraph_testbench.b._s20" (1 members)>,
#  '0x7fc05200b990': <IvlNet: "bargraph_testbench.b._s19" (2 members)>,
#  '0x7fc05200bed0': <IvlNet: "bargraph_testbench.b._s22" (1 members)>,
#  '0x7fc05200c340': <IvlNet: "bargraph_testbench.b._s25" (1 members)>,
#  '0x7fc05200c5d0': <IvlNet: "bargraph_testbench.b._s27" (1 members)>,
#  '0x7fc05200c860': <IvlNet: "bargraph_testbench.b._s29" (2 members)>}
